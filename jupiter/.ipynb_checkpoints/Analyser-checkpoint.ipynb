# %%
## from pandas import DataFrame, read_csv

# General syntax to import a library but no functions:
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number
import glob
import numpy as np
# def combineFiles( inputDir,outputFile ):
#     read_files = glob.glob(inputDir)
#     with open(outputFile, "wb") as outfile:
#         for f in read_files:
#             with open(f, "rb") as infile:
#                 outfile.write(infile.read())
#     return

def prunDataFrame(dataframe):
    dataframe = dataframe[(dataframe['mx'] > 0) & (dataframe['mn'] > 0)  ]
    dataframe = dataframe.drop('geo', 1)
    dataframe = dataframe.drop('mx', 1)
    dataframe = dataframe.drop('mn', 1)
    dataframe = dataframe[['latency','wc']].apply(pd.to_numeric)
   # dataframe = dataframe.drop('window', 1)
    return dataframe

def buildDataFrame(filePath):
    df_temp = pd.read_csv(filePath,names=['geo','latency','mx','mn','wc'])
    df_temp = prunDataFrame(df_temp)
    return df_temp

def pruneForDenseWindows(dataframe,percentage):
    pd.to_numeric(dataframe.wc)
    topWindows = dataframe.wc.quantile(percentage)
    #print(topWindows)
    dataframe = dataframe[dataframe.wc > topWindows  ]
    return dataframe


def pandasDraw(listOfFilePaths,_figsize,_range,_quantile=None):
    for fileGroup in listOfFilePaths:
        df_list = []
        for file in fileGroup:
            column_name = file.rsplit('.', 1)[0]
            temp_df = buildDataFrame(file)
            if not (_quantile is None):
                temp_df = pruneForDenseWindows(temp_df,_quantile)
            temp_df_with_cols = pd.DataFrame({column_name:temp_df.latency},
                    columns=[column_name])
            df_list.append(temp_df_with_cols)
        df_final = pd.concat(df_list)
        ax_df_final = df_final.hist(figsize=_figsize,bins=100,range=_range)
    plt.show()
    








flink_267K_16_4_ts_in_gn = '/Users/jeka01/Desktop/temp/ts_in_generator/flink_267K_16_4.csv'
flink_264K_8_4_ts_in_gn = '/Users/jeka01/Desktop/temp/ts_in_generator/flink_264K_8_4.csv'

spark_260K_16_4_ts_in_gn = '/Users/jeka01/Desktop/temp/ts_in_generator/spark_260K_16_4.csv'
spark_260K_8_4_ts_in_gn = '/Users/jeka01/Desktop/temp/ts_in_generator/spark_260K_8_4.csv'

trident_93K_8_4_ts_in_gn = '/Users/jeka01/Desktop/temp/ts_in_generator/trident_93K_8_4.csv'
trident_97K_16_4_ts_in_gn = '/Users/jeka01/Desktop/temp/ts_in_generator/trident_97K_16_4.csv'

print (' - Timestamp was generated at generator ')
print (' - Keyed Field was generated sequentially rather than random  ')

figsize = (20,8)
range = [0,5000]
pandasDraw([[flink_267K_16_4_ts_in_gn,flink_264K_8_4_ts_in_gn],
           [spark_260K_16_4_ts_in_gn,spark_260K_8_4_ts_in_gn],
           [trident_97K_16_4_ts_in_gn, trident_93K_8_4_ts_in_gn]],
           _figsize=figsize,_range=range)
# Out:
#  - Timestamp was generated at generator
#  - Keyed Field was generated sequentially rather than random

# %%
quant = 0.3

print (' - Timestamp was generated at generator ')
print (' - Keyed Field was generated sequentially rather than random  ')
print (' - Window element counts are higher than  ' + str(quant))

pandasDraw([[flink_267K_16_4_ts_in_gn,flink_264K_8_4_ts_in_gn],
           [spark_260K_16_4_ts_in_gn,spark_260K_8_4_ts_in_gn],
           [trident_97K_16_4_ts_in_gn, trident_93K_8_4_ts_in_gn]],
           _figsize=figsize,
           _range=range,
          _quantile = quant)
# Out:
#  - Timestamp was generated at generator
#  - Keyed Field was generated sequentially rather than random
#  - Window element counts are higher than  0.3

# %%
quant = 0.3

print (' - Timestamp was generated at operator ')
print (' - Keyed Field was generated sequentially rather than random  ')

spark_280K_16_4_ts_in_op = '/Users/jeka01/Desktop/temp/ts_in_operator/spark_280K_16_4.csv'
spark_278K_8_4_ts_in_op = '/Users/jeka01/Desktop/temp/ts_in_operator/spark_278K_8_4.csv'

trident_102K_8_4_ts_in_op = '/Users/jeka01/Desktop/temp/ts_in_operator/trident_102K_8_4.csv'
trident_102K_16_4_ts_in_op = '/Users/jeka01/Desktop/temp/ts_in_operator/trident_102K_16_4.csv'

flink_273K_16_4_ts_in_op = '/Users/jeka01/Desktop/temp/ts_in_operator/flink_273K_16_4.csv'
flink_285K_8_4_ts_in_op = '/Users/jeka01/Desktop/temp/ts_in_operator/flink_285K_8_4.csv'




pandasDraw([[flink_285K_8_4_ts_in_op,flink_273K_16_4_ts_in_op],
           [spark_278K_8_4_ts_in_op,spark_280K_16_4_ts_in_op],
           [trident_102K_8_4_ts_in_op, trident_102K_16_4_ts_in_op]],
           _figsize=figsize,
           _range=range,
          _quantile = None)
# Out:
#  - Timestamp was generated at operator
#  - Keyed Field was generated sequentially rather than random
