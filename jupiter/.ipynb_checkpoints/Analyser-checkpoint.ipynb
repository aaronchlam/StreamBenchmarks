# %%
## from pandas import DataFrame, read_csv

# General syntax to import a library but no functions:
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number
import glob

def combineFiles( inputDir,outputFile ):
    read_files = glob.glob(inputDir)
    with open(outputFile, "wb") as outfile:
        for f in read_files:
            with open(f, "rb") as infile:
                outfile.write(infile.read())
    return





# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/sparkFast/spark-8-2/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/sparkFast/spark8-2.txt')
# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/sparkFast/spark-8-4/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/sparkFast/spark8-4.txt')

# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-1000ps/spark-8-4/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-1000ps/spark8-4.txt')
# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-1000ps/spark-8-2/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-1000ps/spark8-2.txt')

# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-100ps/spark-8-4/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-100ps/spark8-4.txt')
# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-100ps/spark-8-2/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-100ps/spark8-2.txt')

# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-10ps/spark-8-4/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-10ps/spark8-4.txt')
# combineFiles('/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-10ps/spark-8-2/*/*',
#             '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-10ps/spark8-2.txt')





flink_8_2_F = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flinkFast/flink8-2.txt'
flink_8_4_F = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flinkFast/flink8-4.txt'
flink_8_2_1000ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flink-1000ps/flink8-2.txt'
flink_8_4_1000ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flink-1000ps/flink8-4.txt'
flink_8_2_100ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flink-100ps/flink8-2.txt'
flink_8_4_100ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flink-100ps/flink8-4.txt'
flink_8_2_10ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flink-10ps/flink8-2.txt'
flink_8_4_10ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/flink/flink-10ps/flink8-4.txt'

spark_8_2_F = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/sparkFast/spark8-2.txt'
spark_8_4_F = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/sparkFast/spark8-4.txt'
spark_8_2_1000ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-1000ps/spark8-2.txt'
spark_8_4_1000ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-1000ps/spark8-4.txt'
spark_8_2_100ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-100ps/spark8-2.txt'
spark_8_4_100ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-100ps/spark8-4.txt'
spark_8_2_10ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-10ps/spark8-2.txt'
spark_8_4_10ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/spark/spark-10ps/spark8-4.txt'

storm_8_2_F = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/stormFast/storm8-2.txt'
storm_8_4_F = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/stormFast/storm8-4.txt'
storm_8_2_1000ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/storm-1000ps/storm8-2.txt'
storm_8_4_1000ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/storm-1000ps/storm8-4.txt'
storm_8_2_100ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/storm-100ps/storm8-2.txt'
storm_8_4_100ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/storm-100ps/storm8-4.txt'
storm_8_2_10ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/storm-10ps/storm8-2.txt'
storm_8_4_10ps = '/Users/jeka01/Documents/workspaces/benchmarking/streaming-benchmarks-master/output/storm/storm-10ps/storm8-4.txt'



df_flink_8_2_F = pd.read_csv(flink_8_2_F,names=['latency'])
df_flink_8_2_F.latency = df_flink_8_2_F.latency / 1000000
df_flink_8_4_F = pd.read_csv(flink_8_4_F,names=['latency'])
df_flink_8_4_F.latency = df_flink_8_4_F.latency / 1000000

df_flink_8_2_1000ps = pd.read_csv(flink_8_2_1000ps,names=['latency'])
df_flink_8_2_1000ps.latency = df_flink_8_2_1000ps.latency / 1000000
df_flink_8_4_1000ps = pd.read_csv(flink_8_4_1000ps,names=['latency'])
df_flink_8_4_1000ps.latency = df_flink_8_4_1000ps.latency / 1000000

df_flink_8_2_100ps = pd.read_csv(flink_8_2_100ps,names=['latency'])
df_flink_8_2_100ps.latency = df_flink_8_2_100ps.latency / 1000000
df_flink_8_4_100ps = pd.read_csv(flink_8_4_100ps,names=['latency'])
df_flink_8_4_100ps.latency = df_flink_8_4_100ps.latency / 1000000

df_flink_8_2_10ps = pd.read_csv(flink_8_2_10ps,names=['latency'])
df_flink_8_2_10ps.latency = df_flink_8_2_10ps.latency / 1000000
df_flink_8_4_10ps = pd.read_csv(flink_8_4_10ps,names=['latency'])
df_flink_8_4_10ps.latency = df_flink_8_4_10ps.latency / 1000000


df_spark_8_2_F = pd.read_csv(spark_8_2_F,names=['latency'])
df_spark_8_2_F.latency = df_spark_8_2_F.latency / 1000000
df_spark_8_4_F = pd.read_csv(spark_8_4_F,names=['latency'])
df_spark_8_4_F.latency = df_spark_8_4_F.latency / 1000000

df_spark_8_2_1000ps = pd.read_csv(spark_8_2_1000ps,names=['latency'])
df_spark_8_2_1000ps.latency = df_spark_8_2_1000ps.latency / 1000000
df_spark_8_4_1000ps = pd.read_csv(spark_8_4_1000ps,names=['latency'])
df_spark_8_4_1000ps.latency = df_spark_8_4_1000ps.latency / 1000000

df_spark_8_2_100ps = pd.read_csv(spark_8_2_100ps,names=['latency'])
df_spark_8_2_100ps.latency = df_spark_8_2_100ps.latency / 1000000
df_spark_8_4_100ps = pd.read_csv(spark_8_4_100ps,names=['latency'])
df_spark_8_4_100ps.latency = df_spark_8_4_100ps.latency / 1000000

df_spark_8_2_10ps = pd.read_csv(spark_8_2_10ps,names=['latency'])
df_spark_8_2_10ps.latency = df_spark_8_2_10ps.latency / 1000000
df_spark_8_4_10ps = pd.read_csv(spark_8_4_10ps,names=['latency'])
df_spark_8_4_10ps.latency = df_spark_8_4_10ps.latency / 1000000



df_storm_8_2_F = pd.read_csv(storm_8_2_F,names=['latency'])
df_storm_8_2_F.latency = df_storm_8_2_F.latency / 1000000
df_storm_8_4_F = pd.read_csv(storm_8_4_F,names=['latency'])
df_storm_8_4_F.latency = df_storm_8_4_F.latency / 1000000

df_storm_8_2_1000ps = pd.read_csv(storm_8_2_1000ps,names=['latency'])
df_storm_8_2_1000ps.latency = df_storm_8_2_1000ps.latency / 1000000
df_storm_8_4_1000ps = pd.read_csv(storm_8_4_1000ps,names=['latency'])
df_storm_8_4_1000ps.latency = df_storm_8_4_1000ps.latency / 1000000

df_storm_8_2_100ps = pd.read_csv(storm_8_2_100ps,names=['latency'])
df_storm_8_2_100ps.latency = df_storm_8_2_100ps.latency / 1000000
df_storm_8_4_100ps = pd.read_csv(storm_8_4_100ps,names=['latency'])
df_storm_8_4_100ps.latency = df_storm_8_4_100ps.latency / 1000000

df_storm_8_2_10ps = pd.read_csv(storm_8_2_10ps,names=['latency'])
df_storm_8_2_10ps.latency = df_storm_8_2_10ps.latency / 1000000
df_storm_8_4_10ps = pd.read_csv(storm_8_4_10ps,names=['latency'])
df_storm_8_4_10ps.latency = df_storm_8_4_10ps.latency / 1000000




print ('\n Latency of Flink with different data frequencies\n')
#df_flink_8_2_F.latency.plot.hist(color='b' )
#plt.show()


df4 = pd.DataFrame({'Highest_flink':df_flink_8_2_F.latency, '1000ps-flink': df_flink_8_2_1000ps.latency,
                    '100ps-flink': df_flink_8_2_100ps.latency,'10ps-flink' : df_flink_8_2_10ps.latency},
                   columns=['Highest_flink','1000ps-flink','100ps-flink','10ps-flink'])
#df4.plot.hist(figsize=(15, 10),bins=50)
ax=df4.plot.bar(figsize=(15, 10))
ax.set_xlim(55)

#print(df_flink)
#df4.diff().hist()
plt.show()
# Out:
#  Latency of Flink with different data frequencies

# %%
df4 = pd.DataFrame({'Highest-spark':df_spark_8_2_F.latency, '1000ps-spark': df_spark_8_2_1000ps.latency,
                    '100ps-spark': df_spark_8_2_100ps.latency,'10ps-spark' : df_spark_8_2_10ps.latency},
                   columns=['Highest-spark','1000ps-spark','100ps-spark','10ps-spark'])
df4.hist(bins=50,figsize=(15, 10) )
plt.show()

# %%
df4 = pd.DataFrame({'Highest-storm':df_storm_8_2_F.latency, '1000ps-storm': df_storm_8_2_1000ps.latency,
                    '100ps-storm': df_storm_8_2_100ps.latency,'10ps-storm' : df_storm_8_2_10ps.latency},
                   columns=['Highest-storm','1000ps-storm','100ps-storm','10ps-storm'])
#df4.hist(bins=50,figsize=(15, 10) )
ax=df4.plot.bar(figsize=(15, 10))
ax.set_xlim(55)
plt.show()

# %%
print('\n Flink vs Storm vs Spark in 8-2 window, High rate \n')
df4 = pd.DataFrame({'storm_8_2_F':df_storm_8_2_F.latency, 'spark_8_2_F': df_spark_8_2_F.latency,
                    'flink_8_2_F': df_flink_8_2_F.latency},
                   columns=['storm_8_2_F','spark_8_2_F','flink_8_2_F'])
#df4.hist(bins=50,figsize=(15, 10) )
ax=df4.plot.bar(figsize=(15, 10))
ax.set_xlim(55)


plt.show()
# Out:
#  Flink vs Storm vs Spark in 8-2 window, High rate

# %%
print('\n Flink vs Storm vs Spark in 8-4 window, High rate \n')
df4 = pd.DataFrame({'storm_8_4_F':df_storm_8_4_F.latency, 'spark_8_4_F': df_spark_8_4_F.latency,
                    'flink_8_4_F': df_flink_8_4_F.latency},
                   columns=['storm_8_4_F','spark_8_4_F','flink_8_4_F'])
df4.hist(bins=50,figsize=(15, 10) )
plt.show()
# Out:
#  Flink vs Storm vs Spark in 8-4 window, High rate
